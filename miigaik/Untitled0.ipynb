# %% [markdown]
# <a href="https://colab.research.google.com/github/mimiAmmimi/university/blob/main/miigaik/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('123')
# Out:
# 123
